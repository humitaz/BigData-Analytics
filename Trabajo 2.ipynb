# %% [markdown]
# # Trabajo 2 – Computación en Paralelo

# %% [markdown]
# ## Parte I

# %% [markdown]
# Responda las siguientes preguntas respetando el límite máximo de palabras establecido

# %% [markdown]
# 1.	El equipo del QLAB, para el cual Ud. ahora trabaja, ha decidido comprar 100 tarjetas gráficas (GPUs) para PCs a fin de utilizarlas en computación en paralelo para investigación en Ciencias Sociales. Sabiendo de su experiencia en el tema, el director le ha pedido recomendaciones. Elabore una tabla de comparación de, por lo menos, tres tarjetas gráficas disponibles en Perú donde resuma a detalle las especificaciones de cada una de ellas. Finalmente, diga cuál y por qué le recomendaría al director. Recuerde que el precio es uno de los atributos a considerar.  (200 palabras, 3 puntos)

# %% [markdown]
# Si queremos comprar 100 GPUs para 100 PCs individuales las mejores opciones son las líneas, NIVIDIA RTX y NVIDIA Geforce RTX. Hay que considerar que la plataforma CUDA, ampliamente usada para computación en paralelo, es exclusiva de NVIDIA por lo que recomendamos optar por esta compañía. Además, mejor optar por modelos con arquitectura Ampere que tienen mejor performance que su predecesora Turing para tareas de Deep Learning. La línea RTX tiene 6 modelos siendo el A6000 el más potente, sin competencia en el mercado. Esto pues tiene la mayor memoria (poder) con 48 GB, mayor cantidad de unidades de procesamiento (para paralelizar) con 10.752 CUDA cores, incluyendo 336 Tensor cores (procesadores optimizados para IA) y el mayor rendimiento con 38,7 TFLOPs (309,7 TFLOPs para los Tensor cores). Empero, su precio es de 20.562 S/. Alternativamente, las GeForce RTX 3090, optimizadas para videojuegos, tienen características similares a las RTX. Destaca la GeForce RTX 3090 Ti con 10.752 CUDA cores, performance de 40 TFLOPs y memoria de 24 GB a 8.812 soles. Recomendamos entonces comprar diez RTX A6000 para tener algunas computadoras con la última tecnología (estos GPUs también se pueden emparejar para mayor poder) y noventa Geforce RTX 3090 Ti con menos memoria, pero mejor rendimiento a menor precio.

# %%
import pandas as pd
from IPython.display import Image

# %%
Tabla_de_comparacion=pd.read_excel("tabla gpu.xlsx")

# %%
Tabla_de_comparacion
# Out:
#     Unnamed: 0                     Tarjeta  Arquitectura  \
# 0          NaN                          NaN          NaN
# 1          NaN             NVIDIA RTX A6000       Ampere
# 2          NaN             NVIDIA RTX A5500       Ampere
# 3          NaN             NVIDIA RTX A5000       Ampere
# 4          NaN             NVIDIA RTX A4500       Ampere
# 5          NaN             NVIDIA RTX A4000       Ampere
# 6          NaN             NVIDIA RTX A2000       Ampere
# 7          NaN   Nvidia Geforce RTX 3090 Ti       Ampere
# 8          NaN      Nvidia Geforce RTX 3090       Ampere
# 9          NaN             Radeon Pro W6800  AMD RDNA™ 2
# 10         NaN             Radeon Pro W6600  AMD RDNA™ 2
# 11         NaN             Radeon Pro W6400  AMD RDNA™ 2
# 12         NaN  Radeon Pro WX 9100 Graphics         Vega
# 13         NaN                          NaN          NaN
# 14         NaN                          NaN          NaN
# 15         NaN                          NaN          NaN
# 16         NaN                          NaN          NaN
#
#                     Unidades de procesamiento           Unnamed: 4  \
# 0   NVIDIA CUDA Cores o AMD stream processors  NVIDIA Tensor Cores
# 1                                       10752                  336
# 2                                       10240                  320
# 3                                        8192                  256
# 4                                        7168                  224
# 5                                        6144                  192
# 6                                        3328                  104
# 7                                       10752                  336
# 8                                       10496                  328
# 9                                        3840                  NaN
# 10                                       1792                  NaN
# 11                                        768                  NaN
# 12                                       4096                  NaN
# 13                                        NaN                  NaN
# 14                                        NaN                  NaN
# 15                                        NaN                  NaN
# 16                                        NaN                  NaN
#
#     Memoria (GB)          Performance (TFLOPs)          Unnamed: 7  \
# 0            NaN  Peak Single Precision (FP32)  Tensor performance
# 1           48.0                          38.7               309.7
# 2           24.0                          34.1               272.8
# 3           24.0                          27.8               222.2
# 4           20.0                          23.7               189.2
# 5           16.0                          19.2               153.4
# 6           12.0                             8                63.9
# 7           24.0                            40                 320
# 8           24.0                         35.58          No hallado
# 9           32.0                         17.83                 NaN
# 10           8.0                          10.4                 NaN
# 11           4.0                           3.5                 NaN
# 12          16.0                          12.3                 NaN
# 13           NaN                           NaN                 NaN
# 14           NaN                           NaN                 NaN
# 15           NaN                           NaN                 NaN
# 16           NaN                           NaN                 NaN
#
#    Precio unitario (S/) Precio 100 unidades (S/)  Unnamed: 10  \
# 0                   NaN                      NaN          NaN
# 1              20561.99                2056199.0          NaN
# 2            No hallado               No hallado          NaN
# 3               8954.99                   895499          NaN
# 4               6882.99                   688299          NaN
# 5               4026.99                   402699          NaN
# 6               2683.99                   268399          NaN
# 7               8811.99                   881199          NaN
# 8               7760.49                   776049          NaN
# 9            No hallado               No hallado          NaN
# 10           No hallado               No hallado          NaN
# 11           No hallado               No hallado          NaN
# 12              8169.49                   816949          NaN
# 13                  NaN                      NaN          NaN
# 14                  NaN                      NaN          NaN
# 15                  NaN                      NaN          NaN
# 16                  NaN                      NaN          NaN
#
#                                           Unnamed: 11  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  https://www.tradeinn.com/techinn/es/pny-tarjet...
#
#                                           Unnamed: 12
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9        https://www.amd.com/en/graphics/workstations
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  https://www.nvidia.com/es-la/geforce/products/...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN

# %% [markdown]
# Imag/tabla_gpu.png)
